# %% [markdown]
# # Random walk statistics

# %%
from matplotlib import pyplot as plt

# %%
# Pro každou realizaci náhodné procházky načti řádek obsahující souřadnice x, y a vzdálenost.
# Pro každou procházku pak spočti statistiku.

# The encoding depends on terminal settings, here i Used Windows.
# Better to code it in Fortran when writing to the file.
# https://brushingupscience.com/2016/06/21/matplotlib-animations-the-easy-way/

with open("data.psv", encoding="utf-16") as _file:
    data = _file.read()

datas = [_ for _ in data.split("---") if _ != '\n']

walk1 = [walk for walk in [line.split("|") for line in [_ for _ in datas[0].split("\n")] if line != " "]]

len(walk1)

walk1[-1]
# Out:
# ['2.0', '28.0', '28.0713']

# %%
# Get coordinates `x` and `y`.
xs = [_[0] for _ in walk1]
ys = [_[1] for _ in walk1]

print(len(walks), len(xs), len(ys))

# fig, ax = plt.subplots(figsize=(20, 20))
# ax.scatter(xs, ys, marker='.b')
# ax.get_xaxis().set_visible(False)
# ax.get_yaxis().set_visible(False)
# # plt.show()

plt.figure(figsize=(20, 20), dpi=80)
plt.scatter(xs, ys, c="b")
# plt.plot(xs, ys)
plt.show()
# Out:
# 10 10000 10000
